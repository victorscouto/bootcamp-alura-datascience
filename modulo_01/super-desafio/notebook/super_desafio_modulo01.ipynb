# %% [markdown]
# #Super Desafio
#
# ## Montar uma visualização com mais informações do DATASUS
#
# ### Dados
# - Valores aprovados por ano/mês atendimento;
# - Quantidade de óbitos por ano/mês atendimento;
# - Quantidade média de atendimento por ano/mês antendimento.

# %% [markdown]
# #Preparação das bibliotecas e carga dos dados

# %%
#importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#variaveis de working (auxiliares)
wrk_var_milhao = 1.e6

#ajustando formatação de valor decimal para visualizar melhor
pd.options.display.float_format = '{:,.2f}'.format

# %%
#carga dos dados de quantidade de obitos
uri_qtde_obitos="https://raw.githubusercontent.com/victorscouto/bootcamp-alura-datascience/main/dados/qtde_obitos.csv"
dados_qtde_obitos=pd.read_csv(uri_qtde_obitos,
                              encoding= "ISO-8859-1",
                              skiprows= 3,
                              sep=";",
                              skipfooter= 12,
                              thousands=".",
                              decimal=",",
                              engine="python")

# %%
#carga dos dados de tempo medio permanencia no hospital
uri_tempo_medio_permanencia="https://raw.githubusercontent.com/victorscouto/bootcamp-alura-datascience/main/dados/tempo_medio_permanencia.csv"
dados_tempo_medio_permanencia=pd.read_csv(uri_tempo_medio_permanencia,
                              encoding= "ISO-8859-1",
                              skiprows= 3,
                              sep=";",
                              skipfooter= 12,
                              thousands=".",
                              decimal=",",
                              engine="python")

# %%
#carga dos dados de valores totais aprovados
uri_valor_aprovado="https://raw.githubusercontent.com/victorscouto/bootcamp-alura-datascience/main/dados/valores_aprovados_gastos.csv"
dados_valor_aprovado=pd.read_csv(uri_valor_aprovado,
                              encoding= "ISO-8859-1",
                              skiprows= 3,
                              sep=";",
                              skipfooter= 12,
                              thousands=".",
                              decimal=",",
                              engine="python")

# %% [markdown]
# ##Montar bases para correlacionar, montar referências 2010/2020

# %%
colunas_ref_2010_2020 = dados_valor_aprovado.columns[151:283].tolist()
colunas_ref_2010_2020
# Out:
# ['2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez']

# %% [markdown]
# #Preparação e Manipulação dos dados

# %% [markdown]
# ##Avaliação dos dados de obitos

# %%
#filtrando apenas a colunas que possuem dados (retirando colunas com observacoes nulas)
colunas_usaveis_obitos=dados_qtde_obitos.mean().index.tolist()

#inserindo a coluna Unidade da Federação para filtro na lista
colunas_usaveis_obitos.insert(0, "Unidade da Federação")

#montando um novo dataframe para usar a Unidade da Federação como index
usaveis_obitos = dados_qtde_obitos[colunas_usaveis_obitos]

#marcar nomes das regioes
usaveis_obitos["regiao"] = dados_qtde_obitos["Unidade da Federação"].str.slice(stop=1).apply(
    lambda x: 'Norte'    if x == '1' else 
              'Nordeste' if x == '2' else
              'Sudeste'  if x == '3' else
              'Sul'      if x == '4' else 'Centro-Oeste')

#removendo a coluna "Total"
usaveis_obitos = usaveis_obitos.drop(labels="Total", axis=1)

#substituindo o index para "Unidade da Federação"
usaveis_obitos = usaveis_obitos.set_index("Unidade da Federação")

#filtrando apenas os estados da regiao sudeste
obitos_sudeste = usaveis_obitos[usaveis_obitos['regiao'] == 'Sudeste']

#filtrando apenas os estados da regiao nordeste
obitos_nordeste = usaveis_obitos[usaveis_obitos['regiao'] == 'Nordeste']

#filtrando apenas os estados da regiao centro-oeste
obitos_centrooeste = usaveis_obitos[usaveis_obitos['regiao'] == 'Centro-Oeste']

#filtrando apenas os estados da regiao sul
obitos_sul = usaveis_obitos[usaveis_obitos['regiao'] == 'Sul']

#filtrando apenas os estados da regiao norte
obitos_norte = usaveis_obitos[usaveis_obitos['regiao'] == 'Norte']

#plotando para avaliar outlier, algum dado que possa atrapalhar estudos mais detalhados
#usaveis_obitos.T.plot(figsize=(12,6))

#plt.legend(bbox_to_anchor=(1.05,1))
#plt.show

#Avaliando os dados, aparentemente nenhum período atípico
#Base poderia se adequar a amostra das outras bases para cruzar referências
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %% [markdown]
# ##Avaliação de quantidade de óbitos, visualização por Estados da Região Sudeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_obitos_sudeste = obitos_sudeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_obitos_sudeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %% [markdown]
# ##Avaliação de quantidade de óbitos, visualização por Estados da Região Nordeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_obitos_nordeste = obitos_nordeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_obitos_nordeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de quantidade de óbitos, visualização por Estados da Região Norte - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_obitos_norte = obitos_norte[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_obitos_norte.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de quantidade de óbitos, visualização por Estados da Região Sul - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_obitos_sul = obitos_sul[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_obitos_sul.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de quantidade de óbitos, visualização por Estados da Região Centro-Oeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_obitos_centrooeste = obitos_centrooeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_obitos_centrooeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação dos dados de tempo medio de permanencia no hospital

# %%
#filtrando apenas a colunas que possuem dados (retirando colunas com observacoes nulas)
colunas_usaveis_tempo_perm=dados_tempo_medio_permanencia.mean().index.tolist()

#inserindo a coluna Unidade da Federação para filtro na lista
colunas_usaveis_tempo_perm.insert(0, "Unidade da Federação")

#montando um novo dataframe para usar a Unidade da Federação como index
usaveis_tempo_perm = dados_tempo_medio_permanencia[colunas_usaveis_tempo_perm]

#marcar nomes das regioes
usaveis_tempo_perm["regiao"] = dados_tempo_medio_permanencia["Unidade da Federação"].str.slice(stop=1).apply(
    lambda x: 'Norte'    if x == '1' else 
              'Nordeste' if x == '2' else
              'Sudeste'  if x == '3' else
              'Sul'      if x == '4' else 'Centro-Oeste')

#removendo a coluna "Total"
usaveis_tempo_perm = usaveis_tempo_perm.drop(labels="Total", axis=1)

#substituindo o index para "Unidade da Federação"
usaveis_tempo_perm = usaveis_tempo_perm.set_index("Unidade da Federação")

#filtrando apenas os estados da regiao sudeste
tempo_perm_sudeste = usaveis_tempo_perm[usaveis_tempo_perm['regiao'] == 'Sudeste']

#filtrando apenas os estados da regiao nordeste
tempo_perm_nordeste = usaveis_tempo_perm[usaveis_tempo_perm['regiao'] == 'Nordeste']

#filtrando apenas os estados da regiao centro-oeste
tempo_perm_centrooeste = usaveis_tempo_perm[usaveis_tempo_perm['regiao'] == 'Centro-Oeste']

#filtrando apenas os estados da regiao sul
tempo_perm_sul = usaveis_tempo_perm[usaveis_tempo_perm['regiao'] == 'Sul']

#filtrando apenas os estados da regiao norte
tempo_perm_norte = usaveis_tempo_perm[usaveis_tempo_perm['regiao'] == 'Norte']

#plotando para avaliar outlier, algum dado que possa atrapalhar estudos mais detalhados
#usaveis_tempo_perm.T.plot(figsize=(12,6))

#plt.legend(bbox_to_anchor=(1.05,1))
#plt.show

#usaveis_tempo_perm.T.head(24)

#algumas conclusões relevantes:
#---> Neste arquivo que estamos estudando, os dados de 2007 estão apresentando comportamento estranho
#---> O Estado de São Paulo em 2008/Jan ainda está com um valor outlier, muito disproporcional ao restante
#---> É provavel que utilizar a partir de 2010, será uma leitura de dados mais padronizados
#---> (Estou tentando fugir de problemas de "represamento dos dados")

# %% [markdown]
# ##Avaliação de tempo médio permanência no hospital, visualização por Estados da Região Sudeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_tempo_perm_sudeste = tempo_perm_sudeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_tempo_perm_sudeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %% [markdown]
# ##Avaliação de tempo médio permanência no hospital, visualização por Estados da Região Nordeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_tempo_perm_nordeste = tempo_perm_nordeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_tempo_perm_nordeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de tempo médio permanência no hospital, visualização por Estados da Região Norte - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_tempo_perm_norte = tempo_perm_norte[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_tempo_perm_norte.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de tempo médio permanência no hospital, visualização por Estados da Região Sul - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_tempo_perm_sul = tempo_perm_sul[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_tempo_perm_sul.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de tempo médio permanência no hospital, visualização por Estados da Região Centro-Oeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_tempo_perm_centrooeste = tempo_perm_centrooeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_tempo_perm_centrooeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação dos dados de valor aprovado

# %%
#filtrando apenas a colunas que possuem dados (retirando colunas com observacoes nulas)
colunas_usaveis_valor_aprovado=dados_valor_aprovado.mean().index.tolist()

#inserindo a coluna Unidade da Federação para filtro na lista
colunas_usaveis_valor_aprovado.insert(0, "Unidade da Federação")

#montando um novo dataframe para usar a Unidade da Federação como index
usaveis_valor_aprovado = dados_valor_aprovado[colunas_usaveis_valor_aprovado]

#marcar nomes das regioes
usaveis_valor_aprovado["regiao"] = dados_valor_aprovado["Unidade da Federação"].str.slice(stop=1).apply(
    lambda x: 'Norte'    if x == '1' else 
              'Nordeste' if x == '2' else
              'Sudeste'  if x == '3' else
              'Sul'      if x == '4' else 'Centro-Oeste')

#removendo a coluna "Total"
usaveis_valor_aprovado = usaveis_valor_aprovado.drop(labels="Total", axis=1)

#substituindo o index para "Unidade da Federação"
usaveis_valor_aprovado = usaveis_valor_aprovado.set_index("Unidade da Federação")

#plotando para avaliar outlier, algum dado que possa atrapalhar estudos mais detalhados
#usaveis_valor_aprovado[colunas_ref_2010_2020].T.plot(figsize=(12,6))

#filtrando apenas os estados da regiao sudeste
valores_aprovados_sudeste = usaveis_valor_aprovado[usaveis_valor_aprovado['regiao'] == 'Sudeste']

#filtrando apenas os estados da regiao nordeste
valores_aprovados_nordeste = usaveis_valor_aprovado[usaveis_valor_aprovado['regiao'] == 'Nordeste']

#filtrando apenas os estados da regiao centro-oeste
valores_aprovados_centrooeste = usaveis_valor_aprovado[usaveis_valor_aprovado['regiao'] == 'Centro-Oeste']

#filtrando apenas os estados da regiao sul
valores_aprovados_sul = usaveis_valor_aprovado[usaveis_valor_aprovado['regiao'] == 'Sul']

#filtrando apenas os estados da regiao norte
valores_aprovados_norte = usaveis_valor_aprovado[usaveis_valor_aprovado['regiao'] == 'Norte']

#conclusões com esta base, período de 2008/Jan é uma amostra com outlier
#possivelmente algum problema de cadastramento
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %% [markdown]
# ##Avaliação de valores aprovados para os Estados da Região Sudeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_valores_aprovados_sudeste = valores_aprovados_sudeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_valores_aprovados_sudeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %% [markdown]
# ##Avaliação de valores aprovados para os Estados da Região Nordeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_valores_aprovados_nordeste = valores_aprovados_nordeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_valores_aprovados_nordeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de valores aprovados para os Estados da Região Norte - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_valores_aprovados_norte = valores_aprovados_norte[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_valores_aprovados_norte.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de valores aprovados para os Estados da Região Sul - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_valores_aprovados_sul = valores_aprovados_sul[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_valores_aprovados_sul.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Avaliação de valores aprovados para os Estados da Região Centro-Oeste - Amostra 2010-2020

# %%
#plotando apenas as colunas de 2010 a 2020
ax_valores_aprovados_centrooeste = valores_aprovados_centrooeste[colunas_ref_2010_2020].T.plot(figsize=(12,6))
ax_valores_aprovados_centrooeste.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05,1))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#ajustando formatação de valor decimal para visualizar melhor
pd.options.display.float_format = '{:,.2f}'.format

#filtrando apenas a colunas que possuem dados (retirando colunas com observacoes nulas)
colunas_usaveis=dados.mean().index.tolist()

#inserindo a coluna Unidade da Federação para filtro na lista
colunas_usaveis.insert(0, "Unidade da Federação")

#montando um novo dataframe para usar a Unidade da Federação como index
usaveis = dados[colunas_usaveis]

#alterando o index para utilizar a coluna Unidade da Federação
usaveis = usaveis.set_index("Unidade da Federação")

#testando o comando slice com essa nova base
usaveis[["2021/Jan" , "2021/Fev" , "2021/Mar"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bf1b7211eeaa> in <module>()
#       3
#       4 #filtrando apenas a colunas que possuem dados (retirando colunas com observacoes nulas)
# ----> 5 colunas_usaveis=dados.mean().index.tolist()
#       6
#       7 #inserindo a coluna Unidade da Federação para filtro na lista
#
# NameError: name 'dados' is not defined

# %% [markdown]
# ##Os problemas de uma visualização em torta:
#
# - Visualização em fatias é muito difícil de avaliar a proporção ou tamanho
#
# - Gráfico muito difícil de fazer comparação
#
# - Só é fácil de visualizar se ele estiver ordenado, com fácil leitura das legendas e com proporções bem disproporcionais, fácil de visualizar a diferença
#
# - Nunca será um gráfico de informação precisa, necessário tomar muito cuidado para seu uso não gerar informações enviesadas

# %%
#montando um gráfico de pizza para mostrar visualização ruim

#filtramos a última referência (coloquei -2 pois no dataframe usaveis ainda tem a coluna "Total")
mes_mais_recente = usaveis.columns[-2]

#com a referencia do filtro, montamos uma Series com essa referência
amostra_mais_recente = usaveis[mes_mais_recente]

#plotando no formato de torta
amostra_mais_recente.plot(kind='pie')

# %%
#plotando no formato de torta com valores fora de ordem
amostra_mais_recente.sample(frac=1).plot(kind='pie')

# %% [markdown]
# #Desafio #01: Montar uma tabela de comparação para seu estado
#
# ##Para tentar refinar informação com proporções (%)

# %%
#preparando uma amostra correlacionando as proporções de gastos
#sort_values() em uma série de dados não precisa descrever qual coluna será ordenado,
#inclusive se tentar forçar essa informação, vai gerar erro
amostra_mais_recente = amostra_mais_recente.sort_values(ascending=False)
amostra_mais_recente / amostra_mais_recente.loc["35 São Paulo"]

# %%
#montando um plot no formato barra
(amostra_mais_recente / amostra_mais_recente.loc["35 São Paulo"]).plot(kind='bar')

# %% [markdown]
# #Desafio #02: Estudar a documentação matplotlib e Pandas para colocar grid no gráfico

# %%
#montando um plot no formato barra
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#montando um plot em barra de cor vermelha
ax = (amostra_mais_recente / amostra_mais_recente.loc["35 São Paulo"]).plot(kind='bar', color='red')

#ajustando o título do gráfico, ajustando o tamanho da fonte
plt.title( "Valores gastos em saúde, por unidade de Federação", fontsize=14)

#ajustando o ticker para formatar o valor decimal e evitar notação científica
#informação editada aparece no eixo y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

#ajustando texto que irá aparecer no eixo y, editando o tamanho da fonte
ax.set_ylabel("Gastos normalizados por São Paulo", fontsize=10)

#com o método grid() editamos o sentido da linha com o "axis", o estilo da linha
#"linesytle" e a cor com "color"
plt.grid(axis="y", linestyle=':', color='blue')
plt.show()
